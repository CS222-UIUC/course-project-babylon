# %%
""" 
--Liang created Mar 1 2023--
last update Mar 2 2023

working functions that turn csv files of stock data to candle charts

"""

# %%
# %matplotlib inline
import pandas as pd
import mplfinance as mpf
from datetime import datetime
import pandas_datareader as web
import plotly.graph_objs as go
import plotly

# %%
import alpaca_trade_api as tradeapi
import plotly.graph_objects as go
API_KEY = "PKNKABC4NQ6UURX5RU4R"
SECRET_KEY = "0GOzkmT1F5W9rs8czJ90YAXKZrBn6jee3BgGo9le"
BASE_URL = 'https://paper-api.alpaca.markets'

CLIENT_API = tradeapi.REST(key_id= API_KEY, secret_key=SECRET_KEY, base_url=BASE_URL)

def get_stock_data_and_plot_candle(ticker, timeframe, start_date, end_date):
    # Set up the Alpaca API
    # api = tradeapi.REST()
    api = CLIENT_API
    # Get the stock data
    # stock_data = api.get_barset(ticker, timeframe, start=start_date, end=end_date).df[ticker]
    stock_data = api.get_barset(symbol, 'minute', limit=1)

    # Create a candlestick graph
    fig = go.Figure(data=[go.Candlestick(x=stock_data.index,
                    open=stock_data['open'],
                    high=stock_data['high'],
                    low=stock_data['low'],
                    close=stock_data['close'])])

    # Display the graph
    fig.show()
get_stock_data_and_plot_candle('AAPL', 'day', '2022-01-01', '2022-12-31')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 25
#      23     # Display the graph
#      24     fig.show()
# ---> 25 get_stock_data_and_plot_candle('AAPL', 'day', '2022-01-01', '2022-12-31')
#
# Cell In[8], line 14, in get_stock_data_and_plot_candle(ticker, timeframe, start_date, end_date)
#      12 api = CLIENT_API
#      13 # Get the stock data
# ---> 14 stock_data = api.get_barset(ticker, timeframe, start=start_date, end=end_date).df[ticker]
#      16 # Create a candlestick graph
#      17 fig = go.Figure(data=[go.Candlestick(x=stock_data.index,
#      18                 open=stock_data['open'],
#      19                 high=stock_data['high'],
#      20                 low=stock_data['low'],
#      21                 close=stock_data['close'])])
#
# AttributeError: 'REST' object has no attribute 'get_barset'

# %%
#https://www.youtube.com/watch?v=GcXgxfbcFrQ
file = "AMZN.csv"
data = pd.read_csv(file)
data.columns
data
# data.Date = pd.to_datetime(data.Date)
# #data.info()
# data = data.set_index('Date')
# #mpf.plot(data)
# mpf.plot(data['2022-03':'2022-06'],figratio =(20,12), type = 'candle',
#          title = 'Amazon Price 2022',mav = (20),volume=True,tight_layout = True,style = 'yahoo')
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-03-02  150.848999  152.999496  148.750000  152.052505  152.052505
# 1    2022-03-03  153.531494  153.929001  146.856003  147.898499  147.898499
# 2    2022-03-04  147.158997  147.850006  143.807007  145.641006  145.641006
# 3    2022-03-07  145.443497  146.094498  137.416504  137.453003  137.453003
# 4    2022-03-08  136.683502  140.699493  133.572495  136.014496  136.014496
# ..          ...         ...         ...         ...         ...         ...
# 246  2023-02-23   96.120003   96.430000   93.669998   95.820000   95.820000
# 247  2023-02-24   93.529999   94.139999   92.320000   93.500000   93.500000
# 248  2023-02-27   94.279999   94.779999   93.139999   93.760002   93.760002
# 249  2023-02-28   93.139999   94.690002   92.919998   94.230003   94.230003
# 250  2023-03-01   93.870003   94.680000   91.595001   92.169998   92.169998
#
#        Volume
# 0    47334000
# 1    65198000
# ...

# %%
#https://www.youtube.com/watch?v=4fhBXFSS1lc
df= pd.read_csv( "AMZN.csv")
df = df.set_index(pd.DatetimeIndex(df['Date'].values))
figure = go.Figure(data = [
    go.Candlestick(x=df.index,low = df['Low'],high = df['High'],open=df['Open'],close = df ['Close'])
])
# df = df.iloc[::1]
# # df['date'] = pd.to_datetime(df['date'])
# #
# df.Date = pd.to_datetime(df.Date)
# data = df.set_index('Date')
# #
figure.update_layout(
    title = 'Amazon Price',
    yaxis_title = 'Amazon Stock Price USD ($)',
    xaxis_title = 'Date'
)
figure.show()

# %%
start = datetime(2020,1,1)
end = datetime(2020,7,31)
stock = 'TSLA'
df = web.DataReader(stock,'yahoo',start,end)
# df = df.reset_index()
# print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 start = datetime(2020,1,1)
#       2 end = datetime(2020,7,31)
#       3 stock = 'TSLA'
#
# NameError: name 'datetime' is not defined

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    datetime64[ns]
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    datetime64[ns]
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB
